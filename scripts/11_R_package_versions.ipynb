# %%
getwd()
library(tidyverse)
library(Seurat)
library(here)
library(harmony)
library(viridis)
library(RColorBrewer)
library(Polychrome)
PurpleAndYellow()
library(ComplexHeatmap)
library(devtools)
library(presto)
library(dplyr)
library(ggplot2)
library(ggpubr)
library(infercnv)
setwd("/liulab/galib/dlbcl_manuscript/")
source('scripts/scplot.R')
# Out:
# [1] "/liulab/galib/dlbcl_manuscript/scripts"
#  [1] "#FF00FF" "#F400F4" "#EA00EA" "#DF00DF" "#D500D5" "#CA00CA" "#BF00BF"
#  [8] "#B500B5" "#AA00AA" "#9F009F" "#950095" "#8A008A" "#800080" "#750075"
# [15] "#6A006A" "#600060" "#550055" "#4A004A" "#400040" "#350035" "#2B002B"
# [22] "#200020" "#150015" "#0B000B" "#000000" "#000000" "#0B0B00" "#151500"
# [29] "#202000" "#2B2B00" "#353500" "#404000" "#4A4A00" "#555500" "#606000"
# [36] "#6A6A00" "#757500" "#808000" "#8A8A00" "#959500" "#9F9F00" "#AAAA00"
# [43] "#B5B500" "#BFBF00" "#CACA00" "#D4D400" "#DFDF00" "#EAEA00" "#F4F400"
# [50] "#FFFF00"
# Warning message:
# “package ‘infercnv’ was built under R version 4.1.3”

# %%
sessionInfo()
# Out:
# R version 4.1.1 (2021-08-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: CentOS Linux 7 (Core)
#
# Matrix products: default
# BLAS/LAPACK: /liulab/galib/miniconda-Py39/envs/MAESTROv1.6.0/lib/libopenblasp-r0.3.20.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] grid      stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] infercnv_1.10.1       ggpubr_0.4.0          presto_1.0.0
#  [4] data.table_1.14.8     devtools_2.4.3        usethis_2.1.5
#  [7] ComplexHeatmap_2.10.0 Polychrome_1.5.1      RColorBrewer_1.1-3
# [10] viridis_0.6.2         viridisLite_0.4.1     harmony_0.1.0
# [13] Rcpp_1.0.8.3          here_1.0.1            sp_1.5-0
# [16] SeuratObject_4.1.2    Seurat_4.2.0          forcats_0.5.1
# [19] stringr_1.4.1         dplyr_1.0.10          purrr_0.3.4
# [22] readr_2.1.2           tidyr_1.2.0           tibble_3.1.8
# [25] ggplot2_3.3.6         tidyverse_1.3.1
#
# loaded via a namespace (and not attached):
#   [1] pbdZMQ_0.3-7                scattermore_0.8
#   [3] coda_0.19-4                 irlba_2.3.5
#   [5] multcomp_1.4-19             DelayedArray_0.20.0
#   [7] rpart_4.1.16                RCurl_1.98-1.7
#   [9] doParallel_1.0.17           generics_0.1.3
#  [11] BiocGenerics_0.40.0         callr_3.7.3
#  [13] cowplot_1.1.1               lambda.r_1.2.4
#  [15] TH.data_1.1-1               RANN_2.6.1
#  [17] future_1.26.1               tzdb_0.3.0
#  [19] spatstat.data_3.0-4         xml2_1.3.3
#  [21] lubridate_1.8.0             httpuv_1.6.5
#  [23] SummarizedExperiment_1.24.0 assertthat_0.2.1
#  [25] hms_1.1.1                   evaluate_0.16
#  [27] promises_1.2.0.1            argparse_2.1.5
#  [29] fansi_1.0.3                 caTools_1.18.2
#  [31] dbplyr_2.1.1                readxl_1.4.0
#  [33] igraph_1.3.2                DBI_1.1.3
#  [35] htmlwidgets_1.5.4           reshape_0.8.9
#  [37] futile.logger_1.4.3         spatstat.geom_3.2-9
#  [39] stats4_4.1.1                ellipsis_0.3.2
#  [41] backports_1.4.1             libcoin_1.0-9
#  [43] deldir_1.0-6                MatrixGenerics_1.6.0
#  [45] vctrs_0.4.1                 SingleCellExperiment_1.16.0
#  [47] Biobase_2.54.0              remotes_2.4.2
#  [49] ROCR_1.0-11                 abind_1.4-5
#  [51] cachem_1.0.6                withr_2.5.0
#  [53] progressr_0.10.0            sctransform_0.3.5
#  [55] prettyunits_1.1.1           goftest_1.2-3
#  [57] cluster_2.1.3               ape_5.6-2
#  [59] IRdisplay_1.1               lazyeval_0.2.2
#  [61] crayon_1.5.1                edgeR_3.36.0
#  [63] pkgconfig_2.0.3             GenomeInfoDb_1.30.1
#  [65] nlme_3.1-157                pkgload_1.3.0
#  [67] rlang_1.0.3                 globals_0.15.1
#  [69] lifecycle_1.0.1             miniUI_0.1.1.1
#  [71] sandwich_3.0-1              modelr_0.1.8
#  [73] cellranger_1.1.0            rprojroot_2.0.3
#  [75] polyclip_1.10-0             matrixStats_0.62.0
#  [77] lmtest_0.9-40               Matrix_1.5-1
#  [79] IRkernel_1.3.0.9000         carData_3.0-5
#  [81] zoo_1.8-10                  reprex_2.0.1
#  [83] base64enc_0.1-3             ggridges_0.5.3
#  [85] GlobalOptions_0.1.2         processx_3.6.1
#  [87] png_0.1-7                   rjson_0.2.21
#  [89] bitops_1.0-7                KernSmooth_2.23-20
#  [91] shape_1.4.6                 coin_1.4-2
#  [93] parallelly_1.32.0           spatstat.random_3.2-3
#  [95] rstatix_0.7.0               S4Vectors_0.32.4
#  [97] ggsignif_0.6.3              scales_1.2.1
#  [99] memoise_2.0.1               magrittr_2.0.3
# [101] plyr_1.8.7                  ica_1.0-2
# [103] gplots_3.1.3                zlibbioc_1.40.0
# [105] compiler_4.1.1              clue_0.3-60
# [107] fitdistrplus_1.1-8          cli_3.4.0
# [109] XVector_0.34.0              listenv_0.8.0
# [111] patchwork_1.1.1             pbapply_1.5-0
# [113] ps_1.7.1                    formatR_1.12
# [115] MASS_7.3-57                 mgcv_1.8-40
# [117] tidyselect_1.1.2            stringi_1.7.8
# [119] locfit_1.5-9.5              ggrepel_0.9.1
# [121] tools_4.1.1                 future.apply_1.9.0
# [123] parallel_4.1.1              circlize_0.4.15
# [125] rstudioapi_0.13             uuid_1.1-0
# [127] rjags_4-13                  foreach_1.5.2
# [129] gridExtra_2.3               scatterplot3d_0.3-41
# [131] Rtsne_0.16                  digest_0.6.29
# [133] rgeos_0.5-8                 shiny_1.7.1
# [135] GenomicRanges_1.46.1        car_3.0-13
# [137] broom_0.8.0                 later_1.3.0
# [139] RcppAnnoy_0.0.19            httr_1.4.3
# [141] colorspace_2.0-3            rvest_1.0.2
# [143] fs_1.5.2                    tensor_1.5
# [145] reticulate_1.25             IRanges_2.28.0
# [147] splines_4.1.1               uwot_0.1.14
# [149] spatstat.utils_3.0-4        phyclust_0.1-30
# [151] plotly_4.10.0               sessioninfo_1.2.2
# [153] xtable_1.8-4                jsonlite_1.8.0
# [155] futile.options_1.0.1        modeltools_0.2-23
# [157] R6_2.5.1                    pillar_1.8.1
# [159] htmltools_0.5.3             mime_0.12
# [161] glue_1.6.2                  fastmap_1.1.0
# [163] codetools_0.2-18            pkgbuild_1.3.1
# [165] mvtnorm_1.1-3               utf8_1.2.2
# [167] lattice_0.20-45             spatstat.sparse_3.0-3
# [169] leiden_0.4.2                gtools_3.9.2
# [171] survival_3.3-1              limma_3.50.3
# [173] repr_1.1.4                  munsell_0.5.0
# [175] GetoptLong_1.0.5            fastcluster_1.2.3
# [177] GenomeInfoDbData_1.2.7      iterators_1.0.14
# [179] haven_2.5.0                 reshape2_1.4.4
# [181] gtable_0.3.1                spatstat.core_2.4-4
